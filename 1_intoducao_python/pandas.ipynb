# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
# Carregando arquivo para dataframe
dados = pd.read_csv('Credit.csv')

#formato (quantidade de linhas x colunas)
dados.shape
# Out:
# (1000, 21)

# %%
# Resumo estátistico de colunas númericas
dados.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
# Primeiro registro
dados.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
#último registeo , com parâmetro
dados.tail(2)
# Out:
#     checking_status  duration                    credit_history     purpose  \
# 998              <0        45                   'existing paid'    radio/tv
# 999        0<=X<200        45  'critical/other existing credit'  'used car'
#
#      credit_amount savings_status  employment  installment_commitment  \
# 998           1845           <100      1<=X<4                       4
# 999           4576     100<=X<500  unemployed                       3
#
#     personal_status other_parties  ...   property_magnitude age  \
# 998   'male single'          none  ...  'no known property'  23
# 999   'male single'          none  ...                  car  27
#
#      other_payment_plans     housing existing_credits      job num_dependents  \
# 998                 none  'for free'                1  skilled              1
# 999                 none         own                1  skilled              1
#
#      own_telephone foreign_worker class
# 998            yes            yes   bad
# ...

# %%
# Verificando coluna por nome
dados[['duration', 'purpose']]
# Out:
#      duration              purpose
# 0           6             radio/tv
# 1          48             radio/tv
# 2          12            education
# 3          42  furniture/equipment
# 4          24            'new car'
# ..        ...                  ...
# 995        12  furniture/equipment
# 996        30           'used car'
# 997        12             radio/tv
# 998        45             radio/tv
# 999        45           'used car'
#
# [1000 rows x 2 columns]

# %%
# Filtrando linha por indice
dados.loc[1:5]
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
# 5   'no checking'        36                   'existing paid'
#
#                purpose  credit_amount      savings_status employment  \
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
# 5            education           9055  'no known savings'     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# ...

# %%
# Linhas 1 e 5
dados.loc[[1,5]]
# Out:
#   checking_status  duration   credit_history    purpose  credit_amount  \
# 1        0<=X<200        48  'existing paid'   radio/tv           5951
# 5   'no checking'        36  'existing paid'  education           9055
#
#        savings_status employment  installment_commitment  \
# 1                <100     1<=X<4                       2
# 5  'no known savings'     1<=X<4                       2
#
#         personal_status other_parties  ...   property_magnitude age  \
# 1  'female div/dep/mar'          none  ...        'real estate'  22
# 5         'male single'          none  ...  'no known property'  35
#
#    other_payment_plans     housing existing_credits                   job  \
# 1                 none         own                1               skilled
# 5                 none  'for free'                1  'unskilled resident'
#
#   num_dependents  own_telephone foreign_worker class
# 1              1           none            yes   bad
# ...

# %%
# Filtro
dados.loc[dados['duration'] == 48]
# Out:
#     checking_status  duration                    credit_history  \
# 1          0<=X<200        48                   'existing paid'
# 11               <0        48                   'existing paid'
# 36    'no checking'        48  'critical/other existing credit'
# 44               <0        48  'critical/other existing credit'
# 63         0<=X<200        48             'no credits/all paid'
# 115   'no checking'        48  'critical/other existing credit'
# 130        0<=X<200        48                   'existing paid'
# 145        0<=X<200        48                        'all paid'
# 191        0<=X<200        48             'no credits/all paid'
# 226        0<=X<200        48                   'existing paid'
# 242              <0        48             'no credits/all paid'
# 272        0<=X<200        48                        'all paid'
# 273        0<=X<200        48                   'existing paid'
# 286              <0        48                   'existing paid'
# ...

# %%
# Outra confição
dados.loc[dados['credit_amount'] > 14000 ]
# Out:
#     checking_status  duration                    credit_history  \
# 63         0<=X<200        48             'no credits/all paid'
# 95         0<=X<200        54             'no credits/all paid'
# 236        0<=X<200         6                   'existing paid'
# 374        0<=X<200        60                        'all paid'
# 378        0<=X<200        36                   'existing paid'
# 637   'no checking'        60              'delayed previously'
# 714        0<=X<200        60                   'existing paid'
# 744              <0        39  'critical/other existing credit'
# 818              <0        36                   'existing paid'
# 887        0<=X<200        48                   'existing paid'
# 915        0<=X<200        48             'no credits/all paid'
# 917              <0         6                   'existing paid'
#
#                  purpose  credit_amount      savings_status  employment  \
# ...

# %%
# Adicionando em nova tabela
credito = dados.loc[dados['credit_amount'] > 10000]

# %%
credito
# Out:
#     checking_status  duration                    credit_history  \
# 18         0<=X<200        24                   'existing paid'
# 63         0<=X<200        48             'no credits/all paid'
# 87         0<=X<200        36                   'existing paid'
# 95         0<=X<200        54             'no credits/all paid'
# 105        0<=X<200        24  'critical/other existing credit'
# 134   'no checking'        60                   'existing paid'
# 205              <0        30  'critical/other existing credit'
# 226        0<=X<200        48                   'existing paid'
# 236        0<=X<200         6                   'existing paid'
# 272        0<=X<200        48                        'all paid'
# 274              <0        30                   'existing paid'
# 285              <0        47                   'existing paid'
# 304   'no checking'        48  'critical/other existing credit'
# 333   'no checking'        48  'critical/other existing credit'
# ...

# %%
credit03 = dados[['personal_status', 'job', 'foreign_worker']]

# %%
credito3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 credito3
#
# NameError: name 'credito3' is not defined

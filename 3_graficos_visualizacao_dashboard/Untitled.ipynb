# %% [markdown]
# # Histograma com densidade

# %%
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
base = pd.read_csv('Dados/chicken.csv')
base
# Out:
#     weight       feed
# 0      179  horsebean
# 1      160  horsebean
# 2      136  horsebean
# 3      227  horsebean
# 4      217  horsebean
# ..     ...        ...
# 66     359     casein
# 67     216     casein
# 68     222     casein
# 69     283     casein
# 70     332     casein
#
# [71 rows x 2 columns]

# %%
# Criando um dataframe agrupando o atributto feed
agrupado = base.groupby(['feed'])['weight'].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
# Histograma considerando somente um alimento
srn.kdeplot(base.loc[base['feed'] == 'horsebean'].weight).set(title='horsebean')
# Out:
# [Text(0.5, 1.0, 'horsebean')]

# %%
srn.kdeplot(base.loc[base['feed'] == 'casein'].weight).set(title='casein')
# Out:
# [Text(0.5, 1.0, 'casein')]

# %%
srn.kdeplot(base.loc[base['feed'] == 'linseed'].weight).set(title='linseed')
# Out:
# [Text(0.5, 1.0, 'linseed')]

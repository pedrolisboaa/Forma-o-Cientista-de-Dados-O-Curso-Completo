# %%
import pandas as pd
import matplotlib.pyplot as plt

dado = pd.read_csv('Dados/trees.csv')
dado.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# Gerando boxplot
plt.boxplot(dado.Volume, vert=False, showfliers=False, notch=True, patch_artist=True)
plt.title('Árvore')
plt.xlabel('Volume')
# Out:
# Text(0.5, 0, 'Volume')

# %%
# Dados por linha
dado1 = dado.transpose()
plt.boxplot(dado1)
#plt.boxplot(dado, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1edbf146900>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1edbf146e40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1edbf1466c0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1edbf1473e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1edbf1476e0>,
# ...
#  'means': []}

# %%
# Gerando 3 blotplots
plt.boxplot(base.Volume, vert=False)
plt.boxplot(base.Girth, vert=False)
plt.boxplot(base.Height, vert=False)

plt.title('Árvore')
plt.xlabel('')
